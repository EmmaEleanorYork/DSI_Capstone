# %%
import requests
import pandas as pd
import time
import json
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import re

# %%
URL_skincare = "https://www.allure.com/gallery/best-of-beauty-skin-care-product-winners"

URL_drugstore = "https://www.allure.com/gallery/best-of-beauty-drugstore-product-winners"

URL_sensitive = "https://www.allure.com/gallery/best-of-beauty-sensitive-skin-care-product-winners"

#URL_splurge = "https://www.allure.com/gallery/best-of-beauty-luxury-beauty-product-winners"

URL_readers = "https://www.allure.com/gallery/readers-choice-makeup-winners"

# %%
res_skincare = requests.get(URL_skincare, headers = {'User-agent': 'Emma York'})

res_drugstore = requests.get(URL_drugstore, headers = {'User-agent': 'Emma York'})

res_sensitive = requests.get(URL_sensitive, headers = {'User-agent': 'Emma York'})

#res_splurge = requests.get(URL_splurge, headers = {'User-agent': 'Emma York'})

res_readers = requests.get(URL_readers, headers = {'User-agent': 'Emma York'})

# %%
res_skincare.status_code
# Out:
# 200

# %%
html_skincare = res_skincare.text

html_drugstore = res_drugstore.text

html_sensitive = res_sensitive.text

#html_splurge = res_splurge.text

html_readers = res_readers.text

# %%
soup_skincare = BeautifulSoup(html_skincare, 'lxml')
soup_drugstore = BeautifulSoup(html_drugstore, 'lxml')
soup_sensitive = BeautifulSoup(html_sensitive, 'lxml')
#soup_splurge = BeautifulSoup(html_splurge, 'lxml')
soup_readers = BeautifulSoup(html_readers, 'lxml')

# %%
#soup_readers.extract()

# %%
pn_drug = soup_drugstore.find_all('div', {'class': 'gallery-item-title'})
#pn_splurge = soup_sensitive.find_all('div', {'class': 'gallery-item-title'})

# %% [markdown]
# ## Skincare Dataframe

# %%
soup_skincare.extract()
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>33 Best Skin-Care Products of 2018 | Best of Beauty Awards | Allure</title>
# <meta content="no" name="msapplication-tap-highlight"/>
# <meta content="user-scalable=no, width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta content="Liana Schaffner ,Jess Bonham" name="author"/>
# <meta content="Copyright (c) Cond&amp;#233; Nast 2018" name="copyright"/>
# <meta content="The &quot;Skin Care&quot; category of our Best of Beauty Awards is ultra-competitive, but we narrowed it down to 2018's winning cleansers, moisturizers, eye creams, peels, masks, and more. Brighter, smoother, and more radiant: Meet the bottled superstars that'll get your complexion there." name="description"/>
# ...

# %%
type_skin = soup_skincare.find_all('div', {'class': 'gallery-item-title'})       
pn_skin = soup_skincare.find_all('div', {'class': 'caption'})

# %%
len(type_skin)
# Out:
# 33

# %%
len(pn_skin)
# Out:
# 34

# %%
pn_skin_text = [pn_skin[i].find('a', {'rel': 'nofollow'}).text for i in range(0,33)]

type_skin_text = [product_type.text for product_type in type_skin]

# %%
#p = soup_breakthrough.find_all('div', {'class': 'caption'})

price = [price.text for price in pn_skin]

re.findall('\$[\d.]+', price[0])
# Out:
# ['$9']

# %%
skin_price = [re.findall('\$[\d.]+', price[i]) for i in range(0,33)]

# %%
skin_price = [str(x) for [x] in skin_price]

skin_price
# Out:
# ['$9',
#  '$38',
#  '$24',
#  '$6',
#  '$15',
#  '$12',
#  '$28',
#  '$77',
#  '$75',
#  '$49',
#  '$46',
#  '$22',
#  '$36',
#  '$30',
#  '$55',
#  '$19',
#  '$65',
#  '$23',
#  '$42',
#  '$70',
#  '$34',
#  '$32',
#  '$9',
#  '$69',
#  '$45',
#  '$60',
#  '$3',
#  '$14',
#  '$32',
#  '$33',
#  '$48',
#  '$5',
#  '$22']

# %%
skincare_df = pd.DataFrame(
    {'Product Type': type_skin_text,
     'Product Name': pn_skin_text,
     'Price': skin_price,
     'List': "Skincare",
     'Year': '2018'
    })

# %%
skincare_df
# Out:
#                         Product Type  \
# 0       FACIAL CLEANSER: Normal Skin
# 1         FACIAL CLEANSER: Oily Skin
# 2          FACIAL CLEANSER: Dry Skin
# 3   FACIAL CLEANSER: Cleansing Wipes
# 4                    TONER / ESSENCE
# 5                        FACIAL MIST
# 6                         FACIAL OIL
# 7          FACIAL SERUM: Antioxidant
# 8          FACIAL SERUM: Antioxidant
# 9           FACIAL SERUM: Clarifying
# 10             FACIAL SERUM: Calming
# 11             FACIAL SERUM: Retinol
# 12           FACIAL SERUM: Hydrating
# 13   FACIAL MOISTURIZER: Normal Skin
# 14     FACIAL MOISTURIZER: Oily Skin
# 15      FACIAL MOISTURIZER: Dry Skin
# 16         EYE CREAM: Line-Smoothing
# 17         EYE CREAM: Line-Smoothing
# 18              EYE CREAM: Depuffing
# 19           EYE CREAM: Moisturizing
# 20           EYE CREAM: Moisturizing
# 21                      FACIAL SCRUB
# 22                   MASK: Oily Skin
# 23                   MASK: Dull Skin
# ...

# %%
# not sure if i need it, but in case, i would like to split the skin type from the product type column

# %%
skincare_df[['Product Type', 'Skin Type']] = skincare_df['Product Type'].str.split(': ', expand = True)

# %%
skincare_df
# Out:
#           Product Type                                       Product Name  \
# 0      FACIAL CLEANSER  Garnier SkinActive Soothing Rose Water Cleansi...
# 1      FACIAL CLEANSER                            Tatcha The Deep Cleanse
# 2      FACIAL CLEANSER             L’Occitane Shea 3-in-1 Cleansing Water
# 3      FACIAL CLEANSER          Burt’s Bees Micellar Cleansing Towelettes
# 4      TONER / ESSENCE  Lumene Valo Glow Lumenessence Brightening Beau...
# 5          FACIAL MIST  Mario Badescu Facial Spray with Aloe, Chamomil...
# 6           FACIAL OIL      Honest Beauty Magic Organic Beauty Facial Oil
# 7         FACIAL SERUM  Clinique Fresh Pressed Daily Booster with Pure...
# 8         FACIAL SERUM      Korres Wild Rose Spotless Serum 15% Vitamin C
# 9         FACIAL SERUM            Caudalie Vinopure Skin Perfecting Serum
# 10        FACIAL SERUM       Dr. Jart+ Cicapair Tiger Grass Re.Pair Serum
# 11        FACIAL SERUM              Neutrogena Rapid Wrinkle Repair Serum
# ...

# %%
skincare_df.to_csv('allure_skincare_df.csv')

# %% [markdown]
# ## Sensitive Skin

# %%
all_sens = soup_sensitive.find_all('div', {'class': 'gallery-item-title'})       
pn_sens = soup_sensitive.find_all('div', {'class': 'caption'})

# %%
len(pn_sens)
# Out:
# 8

# %%
pn_sens[6].find('a', {'rel': 'nofollow'}).text
# Out:
# 'Coppertone Defend & Care Sensitive Skin Sunscreen SPF 50'

# %%
pn_sens[6].text
# Out:
# 'Coppertone Defend & Care Sensitive Skin Sunscreen SPF 50 serves up heavy-duty UV protection without smothering our pores — or stinging under-eyes.$8 (Shop Now)'

# %%
pn_sens[5]
# Out:
# <div class="caption" data-reactid="356"><div data-reactid="357"><p data-reactid="358"><strong data-reactid="359"><!-- react-text: 360 -->Vaseline Clinical Care Extremely Dry Skin Rescue Healing Moisture Lotion<!-- /react-text --></strong><!-- react-text: 361 --> doesn’t just treat dry skin — it transforms it. Prolipids build a protective barrier to lock in moisture.<!-- /react-text --></p><p data-reactid="362"><!-- react-text: 363 -->$6 (Available in October 2018)<!-- /react-text --></p></div></div>

# %%
pn_sens[5].find('strong').text
# Out:
# 'Vaseline Clinical Care Extremely Dry Skin Rescue Healing Moisture Lotion'

# %%
pn_sens[4]
# Out:
# <div class="caption" data-reactid="325"><div data-reactid="326"><p data-reactid="327"><a data-reactid="328" href="https://shop-links.co/1649191657313117015" rel="nofollow"><!-- react-text: 329 -->La Roche-Posay Lipikar Eczema Soothing Relief Cream<!-- /react-text --></a><!-- react-text: 330 --> relieves scaly skin with a coddling mix of shea butter and colloidal oatmeal.<!-- /react-text --></p><p data-reactid="331"><!-- react-text: 332 -->$15 (<!-- /react-text --><a data-reactid="333" href="https://shop-links.co/1649191657313117015" rel="nofollow"><!-- react-text: 334 -->Shop Now<!-- /react-text --></a><!-- react-text: 335 -->)<!-- /react-text --></p></div></div>

# %%
all_sens_text = [product_type.text for product_type in all_sens]

pn_sens_text = [pn_sens[i].find('a', {'rel': 'nofollow'}).text for i in range(0,5)]

# %%
# since the list stops when i get to a class that doesn't have the rel: nofollow thing, i have to append
# the 6th item manually

pn_sens_text.append(pn_sens[5].find('strong').text)

pn_sens_text
# Out:
# ['Skinfix Foaming Oil Cleanser',
#  'Eau Thermale Avène Intense Eye Make-Up Remover',
#  'Cetaphil Extra Gentle Daily Scrub',
#  'CeraVe Moisturizing Cream',
#  'La Roche-Posay Lipikar Eczema Soothing Relief Cream',
#  'Vaseline Clinical Care Extremely Dry Skin Rescue Healing Moisture Lotion']

# %%
# since my loop broke when it couldn't find the rel: nofollow, my sixth item is also missing. i will
# append it below

pn_sens_text.append(pn_sens[6].find('a', {'rel': 'nofollow'}).text)

# %%
pn_sens_text
# Out:
# ['Skinfix Foaming Oil Cleanser',
#  'Eau Thermale Avène Intense Eye Make-Up Remover',
#  'Cetaphil Extra Gentle Daily Scrub',
#  'CeraVe Moisturizing Cream',
#  'La Roche-Posay Lipikar Eczema Soothing Relief Cream',
#  'Vaseline Clinical Care Extremely Dry Skin Rescue Healing Moisture Lotion',
#  'Coppertone Defend & Care Sensitive Skin Sunscreen SPF 50']

# %%
price_sens = [price.text for price in pn_sens]

sens_price = [re.findall('\$[\d.]+', price_sens[i]) for i in range(0,7)]

# %%
sens_price = [str(x) for [x] in sens_price]

sens_price
# Out:
# ['$22', '$20', '$8', '$17', '$15', '$6', '$8']

# %%
len(all_sens_text), len(pn_sens_text), len(sens_price)
# Out:
# (7, 7, 7)

# %%
all_sens_text
# Out:
# ['FACE CLEANSER',
#  'MAKEUP REMOVER',
#  'FACE SCRUB',
#  'BODY MOISTURIZER',
#  'BODY MOISTURIZER',
#  'BODY MOISTURIZER',
#  'SUNSCREEN']

# %%
pn_sens_text
# Out:
# ['Skinfix Foaming Oil Cleanser',
#  'Eau Thermale Avène Intense Eye Make-Up Remover',
#  'Cetaphil Extra Gentle Daily Scrub',
#  'CeraVe Moisturizing Cream',
#  'La Roche-Posay Lipikar Eczema Soothing Relief Cream',
#  'Vaseline Clinical Care Extremely Dry Skin Rescue Healing Moisture Lotion',
#  'Coppertone Defend & Care Sensitive Skin Sunscreen SPF 50']

# %%
sensitive_df = pd.DataFrame(
            {'Product Type': all_sens_text,
             'Product Name': pn_sens_text,
             'Price': sens_price,
             'Skin Type': 'Sensitive',
             'List': "Sensitive",
             'Year': '2018'
            })

sensitive_df
# Out:
#        Product Type                                       Product Name Price  \
# 0     FACE CLEANSER                       Skinfix Foaming Oil Cleanser   $22
# 1    MAKEUP REMOVER     Eau Thermale Avène Intense Eye Make-Up Remover   $20
# 2        FACE SCRUB                  Cetaphil Extra Gentle Daily Scrub    $8
# 3  BODY MOISTURIZER                          CeraVe Moisturizing Cream   $17
# 4  BODY MOISTURIZER  La Roche-Posay Lipikar Eczema Soothing Relief ...   $15
# 5  BODY MOISTURIZER  Vaseline Clinical Care Extremely Dry Skin Resc...    $6
# 6         SUNSCREEN  Coppertone Defend & Care Sensitive Skin Sunscr...    $8
#
#    Skin Type       List  Year
# 0  Sensitive  Sensitive  2018
# 1  Sensitive  Sensitive  2018
# 2  Sensitive  Sensitive  2018
# 3  Sensitive  Sensitive  2018
# 4  Sensitive  Sensitive  2018
# 5  Sensitive  Sensitive  2018
# 6  Sensitive  Sensitive  2018

# %%
sensitive_df.to_csv('allure_sensitive_df.csv')

# %% [markdown]
# ## Now the Readers Choice!

# %%
type_readers = soup_readers.find_all('div', {'class': 'gallery-item-title'})
pn_readers = soup_readers.find_all('div', {'class': 'caption'})

type_readers_text = [product_type.text for product_type in type_readers]

[product_name.text for product_name in pn_readers]
# Out:
# ['Vapour Organic Beauty Siren LipstickIt’s not surprising that these oil-infused colors are uberhydrating — but that the intense color stays put is near miraculous.$25 (Shop Now)',
#  'Nyx Butter Gloss in Crème BrûléeWant your lips, but better? Reach for this peachy-nude YouTuber (and Allure reader) staple.$5 (Shop Now)',
#  'Tarte Amazonian Clay 12-Hour BlushFor a natural, pinched-cheek flush (without the pain), swipe one of these 13 shades over the apples of your cheeks.$29 (Shop Now)',
#  'Urban Decay Naked2 PaletteIt lives up to the hype (and boy, is there hype). There’s a spectrum of neutrals — and the perfect matte black to seal the deal.$54 (Shop Now)',
#  'Kat Von D Tattoo LinerThe tattoo artist and beauty mogul knows something about sharp lines and proves it with the ultimate glossy, black, nonsmudging liquid liner. Its tapered brush delivers as fine (or fat) a flick as you desire.$20 (Shop Now)',
# ...

# %%
# looks like 'strong' is where i'll find the product name!

pn_readers[6].find('strong').text
# Out:
# 'Nars Radiant Creamy Concealer'

# %%
# checking the length (the last is typically a 'click here for more')

len(pn_readers)
# Out:
# 12

# %%
# here is my product name text!

pn_readers_text = [pn_readers[i].find('strong').text for i in range(0,11)]

pn_readers_text
# Out:
# ['Vapour Organic Beauty Siren Lipstick',
#  'Nyx Butter Gloss in Crème Brûlée',
#  'Tarte Amazonian Clay 12-Hour Blush',
#  'Urban Decay Naked2 Palette',
#  'Kat Von D Tattoo Liner',
#  'L’Oréal Paris Voluminous Lash Paradise Mascara',
#  'Nars Radiant Creamy Concealer',
#  'IT Cosmetics Your Skin But Better CC+ Cream',
#  'Vapour Organic Beauty Atmosphere Luminous Foundation',
#  'OPI Nail Lacquer in Lincoln Park After Dark',
#  'Morphe M433 Pro Firm Blending Fluff Brush']

# %%
[price.text for price in pn_readers]
# Out:
# ['Vapour Organic Beauty Siren LipstickIt’s not surprising that these oil-infused colors are uberhydrating — but that the intense color stays put is near miraculous.$25 (Shop Now)',
#  'Nyx Butter Gloss in Crème BrûléeWant your lips, but better? Reach for this peachy-nude YouTuber (and Allure reader) staple.$5 (Shop Now)',
#  'Tarte Amazonian Clay 12-Hour BlushFor a natural, pinched-cheek flush (without the pain), swipe one of these 13 shades over the apples of your cheeks.$29 (Shop Now)',
#  'Urban Decay Naked2 PaletteIt lives up to the hype (and boy, is there hype). There’s a spectrum of neutrals — and the perfect matte black to seal the deal.$54 (Shop Now)',
#  'Kat Von D Tattoo LinerThe tattoo artist and beauty mogul knows something about sharp lines and proves it with the ultimate glossy, black, nonsmudging liquid liner. Its tapered brush delivers as fine (or fat) a flick as you desire.$20 (Shop Now)',
# ...

# %%
price_readers = [price.text for price in pn_readers]

readers_price = [re.findall('\$[\d.]+', price_readers[i]) for i in range(0,11)]

readers_price # i can see here that the last post talked about two prices, so i will need to get rid of that
# Out:
# [['$25'],
#  ['$5'],
#  ['$29'],
#  ['$54'],
#  ['$20'],
#  ['$10'],
#  ['$30'],
#  ['$38'],
#  ['$46'],
#  ['$11'],
#  ['$6.', '$6']]

# %%
readers_price[10].remove('$6.')

readers_price
# Out:
# [['$25'],
#  ['$5'],
#  ['$29'],
#  ['$54'],
#  ['$20'],
#  ['$10'],
#  ['$30'],
#  ['$38'],
#  ['$46'],
#  ['$11'],
#  ['$6']]

# %%
readers_price = [str(x) for [x] in readers_price]

readers_price
# Out:
# ['$25', '$5', '$29', '$54', '$20', '$10', '$30', '$38', '$46', '$11', '$6']

# %%
readers_df = pd.DataFrame(
            {'Product Type': type_readers_text,
             'Product Name': pn_readers_text,
             'Price': readers_price,
             'Skin Type': 'None',
             'List': "Reader's Choice",
             'Year': '2018'
            })

readers_df
# Out:
#     Product Type                                       Product Name Price  \
# 0       LIPSTICK               Vapour Organic Beauty Siren Lipstick   $25
# 1      LIP GLOSS                   Nyx Butter Gloss in Crème Brûlée    $5
# 2          BLUSH                 Tarte Amazonian Clay 12-Hour Blush   $29
# 3     EYE SHADOW                         Urban Decay Naked2 Palette   $54
# 4       EYELINER                             Kat Von D Tattoo Liner   $20
# 5        MASCARA     L’Oréal Paris Voluminous Lash Paradise Mascara   $10
# 6      CONCEALER                      Nars Radiant Creamy Concealer   $30
# 7    BB/CC CREAM        IT Cosmetics Your Skin But Better CC+ Cream   $38
# 8     FOUNDATION  Vapour Organic Beauty Atmosphere Luminous Foun...   $46
# 9    NAIL POLISH        OPI Nail Lacquer in Lincoln Park After Dark   $11
# 10  MAKEUP BRUSH          Morphe M433 Pro Firm Blending Fluff Brush    $6
#
#    Skin Type             List  Year
# 0       None  Reader's Choice  2018
# ...

# %%
readers_df.to_csv('allure_readers_df.csv')

# %% [markdown]
# ## Primer time!

# %%
URL_base = "https://www.allure.com/gallery/best-of-beauty-base-makeup-product-winners"

res_base = requests.get(URL_base, headers = {'User-agent': 'Emma York'})

html_base = res_base.text

soup_base = BeautifulSoup(html_base, 'lxml')

# %%
type_base = soup_base.find_all('div', {'class': 'gallery-item-title'})

len(type_base)
# Out:
# 23

# %%
type_base[22]
# Out:
# <div class="gallery-item-title" data-reactid="1015"><strong>SETTING SPRAY</strong></div>

# %%
type_base_text = [product_type.text for product_type in type_base]

type_base_text
# Out:
# ['PRIMER',
#  'PRIMER',
#  'PRIMER',
#  'FOUNDATION: Light Coverage',
#  'FOUNDATION: Medium Coverage',
#  'FOUNDATION: Full Coverage',
#  'FOUNDATION: Long-Wearing',
#  'FOUNDATION: BB Cream / Tinted Moisturizer',
#  'BLUSH: Powder',
#  'BLUSH: Cream',
#  'HIGHLIGHTER: Powder',
#  'HIGHLIGHTER: Liquid',
#  'HIGHLIGHTER: Cream',
#  'HIGHLIGHTER: Holographic',
#  'CONTOUR KIT',
#  'POWDER: Pressed',
#  'POWDER: Loose',
#  'CONCEALER: Under-Eyes',
#  'CONCEALER: Blemishes',
#  'FACIAL SELF-TANNER',
#  'BRONZER: Matte',
#  'BRONZER: Shimmer',
#  'SETTING SPRAY']

# %%
pn_base = soup_base.find_all('div', {'class': 'caption'})

# %%
pn_base
# Out:
# [<div class="caption" data-reactid="171"><div data-reactid="172"><p data-reactid="173"><!-- react-text: 174 -->A thin layer of <!-- /react-text --><a data-reactid="175" href="https://shop-links.co/1649283875384371001" rel="nofollow"><!-- react-text: 176 -->L’Oréal Paris Infallible Matte-Lock Mattifying Primer<!-- /react-text --></a><!-- react-text: 177 --> absorbs oil and blurs pores, delivering a Facetuned-like finish that lasts all day.<!-- /react-text --></p><p data-reactid="178"><!-- react-text: 179 -->$13 (<!-- /react-text --><a data-reactid="180" href="https://shop-links.co/1649283875384371001" rel="nofollow"><!-- react-text: 181 -->Shop Now<!-- /react-text --></a><!-- react-text: 182 -->)<!-- /react-text --></p></div></div>,
# ...

# %%
len(pn_base)
# Out:
# 24

# %%
pn_base[22].find('a', {'rel': 'nofollow'})
# Out:
# <a data-reactid="1020" href="https://shop-links.co/1649285665788572679" rel="nofollow"><!-- react-text: 1021 -->Urban Decay All Nighter Long Lasting Makeup Setting Spray<!-- /react-text --></a>

# %%
pn_base_text = [pn_base[i].find('a').text for i in range(0,23)]

# %%
price_base = [price.text for price in pn_base]

base_price = [re.findall('\$[\d.]+', price_base[i]) for i in range(0,23)]

# %%
base_price = [str(x) for [x] in base_price]

# %%
base_df = pd.DataFrame(
            {'Product Type': type_base_text,
             'Product Name': pn_base_text,
             'Price': base_price,
             'Skin Type': 'None',
             'List': "Bases",
             'Year': '2018'
            })

base_df
# Out:
#                                  Product Type  \
# 0                                      PRIMER
# 1                                      PRIMER
# 2                                      PRIMER
# 3                  FOUNDATION: Light Coverage
# 4                 FOUNDATION: Medium Coverage
# 5                   FOUNDATION: Full Coverage
# 6                    FOUNDATION: Long-Wearing
# 7   FOUNDATION: BB Cream / Tinted Moisturizer
# 8                               BLUSH: Powder
# 9                                BLUSH: Cream
# 10                        HIGHLIGHTER: Powder
# 11                        HIGHLIGHTER: Liquid
# 12                         HIGHLIGHTER: Cream
# 13                   HIGHLIGHTER: Holographic
# 14                                CONTOUR KIT
# 15                            POWDER: Pressed
# 16                              POWDER: Loose
# 17                      CONCEALER: Under-Eyes
# 18                       CONCEALER: Blemishes
# ...

# %%
base_df.to_csv('allure_base_df.csv')

# %% [markdown]
# ## Body time!!

# %%
URL_body = "https://www.allure.com/gallery/best-of-beauty-body-skin-care-product-winners"

res_body = requests.get(URL_body, headers = {'User-agent': 'Emma York'})

html_body = res_body.text

soup_body = BeautifulSoup(html_body, 'lxml')

# %%
type_body = soup_body.find_all('div', {'class': 'gallery-item-title'})

# %%
type_body_text = [product_type.text for product_type in type_body]

type_body_text
# Out:
# ['BODY WASH: Moisturizing',
#  'BODY WASH: Exfoliating',
#  'BODY WASH: Bar',
#  'BODY SCRUB',
#  'BODY LOTION: Light',
#  'BODY LOTION: Rich',
#  'BODY LOTION: Spot Treatment',
#  'BODY LOTION: Oil',
#  'BODY SUNSCREEN',
#  'BODY SUNSCREEN',
#  'BODY BRONZER: Traditional Self-Tanner',
#  'BODY BRONZER: Gradual Self-Tanner',
#  'BODY BRONZER: Bronzer',
#  'BATH PRODUCT',
#  'DEODORANT',
#  'ANTIPERSPIRANT',
#  'HAIR REMOVAL: Shaving Cream',
#  'HAIR REMOVAL: Razor',
#  'HAIR REMOVAL: Trimmer',
#  'TEETH WHITENER']

# %%
len(type_body_text)
# Out:
# 20

# %%
type_body_text[19]
# Out:
# 'TEETH WHITENER'

# %%
pn_body = soup_body.find_all('div', {'class': 'caption'})

pn_body_text = [pn_body[i].find('a').text for i in range(0,20)]

# %%
len(pn_body_text)
# Out:
# 20

# %%
pn_body_text[19]
# Out:
# 'Crest 3D White Professional Effects Whitestrips'

# %%
price_body = [price.text for price in pn_body]

body_price = [re.findall('\$[\d.]+', price_body[i]) for i in range(0,20)]

# %%
body_price = [str(x) for [x] in body_price]

# %%
body_df = pd.DataFrame(
            {'Product Type': type_body_text,
             'Product Name': pn_body_text,
             'Price': body_price,
             'Skin Type': 'none',
             'List': "Body Products",
             'Year': '2018'
            })

body_df
# Out:
#                              Product Type  \
# 0                 BODY WASH: Moisturizing
# 1                  BODY WASH: Exfoliating
# 2                          BODY WASH: Bar
# 3                              BODY SCRUB
# 4                      BODY LOTION: Light
# 5                       BODY LOTION: Rich
# 6             BODY LOTION: Spot Treatment
# 7                        BODY LOTION: Oil
# 8                          BODY SUNSCREEN
# 9                          BODY SUNSCREEN
# 10  BODY BRONZER: Traditional Self-Tanner
# 11      BODY BRONZER: Gradual Self-Tanner
# 12                  BODY BRONZER: Bronzer
# 13                           BATH PRODUCT
# 14                              DEODORANT
# 15                         ANTIPERSPIRANT
# 16            HAIR REMOVAL: Shaving Cream
# 17                    HAIR REMOVAL: Razor
# 18                  HAIR REMOVAL: Trimmer
# 19                         TEETH WHITENER
#
# ...

# %%
body_df.to_csv('allure_body_df.csv')

# %% [markdown]
# ## Natural Products Time!!

# %%
URL_natural = "https://www.allure.com/gallery/readers-choice-natural-product-winners"

res_natural = requests.get(URL_natural, headers = {'User-agent': 'Emma York'})

html_natural = res_natural.text

soup_natural = BeautifulSoup(html_natural, 'lxml')

# %%
type_natural = soup_natural.find_all('div', {'class': 'gallery-item-title'})

# %%
type_natural_text = [product_type.text for product_type in type_natural]

type_natural_text
# Out:
# ['FACIAL CLEANSER',
#  'FACIAL MOISTURIZER',
#  'FACIAL SUNSCREEN',
#  'BODY LOTION',
#  'BODY SUNSCREEN',
#  'SHAMPOO AND CONDITIONER',
#  'STYLING CREAM',
#  'MASCARA',
#  'EYE SHADOW',
#  'BLUSH',
#  'FOUNDATION',
#  'CONCEALER',
#  'TINTED MOISTURIZER',
#  'LIP BALM',
#  'LIPSTICK']

# %%
len(type_natural_text)
# Out:
# 15

# %%
pn_body = soup_body.find_all('div', {'class': 'caption'})

pn_body_text = [pn_body[i].find('a').text for i in range(0,20)]

# %%
pn_natural = soup_natural.find_all('div', {'class': 'caption'})

pn_natural_text = [pn_natural[i].find('a').text for i in range(0,15)]

# %%
pn_natural_text
# Out:
# ['Tata Harper Regenerating Cleanser',
#  'Drunk Elephant Lala Retro Whipped Cream',
#  'Drunk Elephant Umbra Sheer Physical Daily Defense SPF 30',
#  'Alba Botanica Very Emollient Body Lotion in Original',
#  'Alba Botanica Hawaiian Sunscreen Green Tea SPF 45',
#  "Carol's Daughter Black Vanilla Moisture & Shine Sulfate-Free Shampoo",
#  'Aveda Smooth Infusion Naturally Straight',
#  'BareMinerals Flawless Definition Mascara',
#  'BareMinerals Ready Eyeshadow 8.0 in The Power Neutrals',
#  'BareMinerals Ready Blush',
#  'BareMinerals Original Foundation',
#  'BareMinerals Correcting Concealer',
#  'BareMinerals Complexion Rescue Tinted Hydrating Gel Cream',
#  'Burt’s Bees Beeswax Lip Balm',
#  'Burt’s Bees Lipstick in Juniper Water']

# %%
price_natural = [price.text for price in pn_natural]

natural_price = [re.findall('\$[\d.]+', price_natural[i]) for i in range(0,15)]

# %%
natural_price[5].remove('$10')

natural_price
# Out:
# [['$82'],
#  ['$60'],
#  ['$34'],
#  ['$12'],
#  ['$9'],
#  ['$12'],
#  ['$26'],
#  ['$19'],
#  ['$41'],
#  ['$24'],
#  ['$29'],
#  ['$21'],
#  ['$30'],
#  ['$3'],
#  ['$9']]

# %%
natural_price = [str(x) for [x] in natural_price]

# %%
natural_df = pd.DataFrame(
            {'Product Type': type_natural_text,
             'Product Name': pn_natural_text,
             'Price': natural_price,
             'Skin Type': 'none',
             'List': "Natural Products",
             'Year': '2018'
            })

natural_df
# Out:
#                Product Type  \
# 0           FACIAL CLEANSER
# 1        FACIAL MOISTURIZER
# 2          FACIAL SUNSCREEN
# 3               BODY LOTION
# 4            BODY SUNSCREEN
# 5   SHAMPOO AND CONDITIONER
# 6             STYLING CREAM
# 7                   MASCARA
# 8                EYE SHADOW
# 9                     BLUSH
# 10               FOUNDATION
# 11                CONCEALER
# 12       TINTED MOISTURIZER
# 13                 LIP BALM
# 14                 LIPSTICK
#
#                                          Product Name Price Skin Type  \
# 0                   Tata Harper Regenerating Cleanser   $82      none
# 1             Drunk Elephant Lala Retro Whipped Cream   $60      none
# 2   Drunk Elephant Umbra Sheer Physical Daily Defe...   $34      none
# 3   Alba Botanica Very Emollient Body Lotion in Or...   $12      none
# 4   Alba Botanica Hawaiian Sunscreen Green Tea SPF 45    $9      none
# 5   Carol's Daughter Black Vanilla Moisture & Shin...   $12      none
# ...

# %%
natural_df.to_csv('allure_natural_df.csv')

# %%
allure_2018 = natural_df.append([skincare_df, readers_df, sensitive_df, body_df, base_df], 
                                ignore_index=True)
# Out:
# /Users/emmaeleanoryork/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
allure_2018
# Out:
#                  List Price  \
# 0    Natural Products   $82
# 1    Natural Products   $60
# 2    Natural Products   $34
# 3    Natural Products   $12
# 4    Natural Products    $9
# 5    Natural Products   $12
# 6    Natural Products   $26
# 7    Natural Products   $19
# 8    Natural Products   $41
# 9    Natural Products   $24
# 10   Natural Products   $29
# 11   Natural Products   $21
# 12   Natural Products   $30
# 13   Natural Products    $3
# 14   Natural Products    $9
# 15           Skincare    $9
# 16           Skincare   $38
# 17           Skincare   $24
# 18           Skincare    $6
# 19           Skincare   $15
# 20           Skincare   $12
# 21           Skincare   $28
# 22           Skincare   $77
# 23           Skincare   $75
# 24           Skincare   $49
# 25           Skincare   $46
# 26           Skincare   $22
# 27           Skincare   $36
# 28           Skincare   $30
# 29           Skincare   $55
# ..                ...   ...
# 79      Body Products   $35
# ...

# %%
allure_2018.to_csv('allure_2018.csv')

# %%
import nltk
words = nltk.word_tokenize(my_text)
my_bigrams = nltk.bigrams(words)
my_trigrams = nltk.trigrams(words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-9c9f08ecb4ee> in <module>
#       1 import nltk
# ----> 2 words = nltk.word_tokenize(my_text)
#       3 my_bigrams = nltk.bigrams(words)
#       4 my_trigrams = nltk.trigrams(words)
#
# NameError: name 'my_text' is not defined

# %%
from sklearn.feature_extraction.text import CountVectorizer 
text = "this is a foo bar sentences and i want to ngramize it"
vectorizer = CountVectorizer(ngram_range=(1,6))
analyzer = vectorizer.build_analyzer()
print analyzer(text)

# %% [markdown]
# ## Breakthrough? Didn't use

# %%
# URL_breakthrough = "https://www.allure.com/gallery/best-of-beauty-new-breakthrough-product-winners"

# res_breakthrough = requests.get(URL_breakthrough, headers = {'User-agent': 'Emma York'})

# html_breakthrough = res_breakthrough.text

# soup_breakthrough = BeautifulSoup(html_breakthrough, 'lxml')

# pn_break = soup_breakthrough.find_all('div', {'class': 'gallery-item-title'})

# %%
# [product_name.text for product_name in pn_break]

# %% [markdown]
# ### 2017? Maybe

# %%
URL_2017 = "https://www.allure.com/gallery/best-of-beauty-2017-winners"

res_2017 = requests.get(URL_2017, headers = {'User-agent': 'Emma York'})

html_2017 = res_2017.text

soup_2017 = BeautifulSoup(html_2017, 'lxml')

# %%
soup_2017.text
# Out:
# '\n\n\n\nAllure Magazine\'s Best of Beauty Award Winners 2017 | Allure\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n{"@context":"https://schema.org","@type":"NewsArticle","headline":"Allure Magazine\'s Best of Beauty Award Winners 2017","alternativeHeadline":"These Are the Winners of Our Best of Beauty Awards for 2017","articleBody":"These Are the Winners of Our Best of Beauty Awards for 2017\\\\nBelow, you can find the winners for Allure&#39;s Best of Beauty Awards in 2017, including all our beauty editors&#39; favorite brands and products of the year, plus hair care, skin care, makeup, and more. And don&#39;t forget to check our latest and greatest winners.\\\\nBrighter, smoother, healthier, beautiful-er: Meet the bottled superstars that get you there.  \\\\n\\\\n__Facial Cleanser (Normal):__ Glossier Milky Jelly Cleanser, $18 ([Shop Now](http://shop-links.co/1614299248993824718){: rel=nofollow})  \\\\n\\\\n__Facial Cleanser (Oily):__ Skinfix Foaming Clay Cleanser, $20 ([Sh
# ...

# %%
re.findall(':__ (.*?),',soup_2017.text)
# Out:
# ['Glossier Milky Jelly Cleanser',
#  'Skinfix Foaming Clay Cleanser',
#  'Rodan + Fields Soothe Gentle Cream Wash',
#  'Mustela Facial Cleansing Wipes',
#  'Julep Love Your Bare Face Detoxifying Cleansing Stick',
#  'Fresh Rose Deep Hydration Facial Toner',
#  'H2O+ AquaDefense Shielding Matcha Facial Essence',
#  'Caudalie Vine Activ Overnight Detox Night Oil',
#  'Aveeno Absolutely Ageless Intensive Renewal Serum',
#  'RoC Retinol Correxion Deep Wrinkle Daily Moisturizer',
#  'No7 Lift & Luminate Triple Action Serum',
#  'Olay Luminous Miracle Boost Concentrate',
#  'L’Oréal Paris Hydra Genius Daily Liquid Care Moisturizer',
#  'Estée Lauder DayWear Matte Oil-Control Antioxidant Moisture Gel Creme',
#  'Garnier SkinActive Moisture Bomb the Antioxidant Super Moisturizer',
#  'StriVectin Retinol Eye Cream',
#  'First Aid Beauty Eye Duty Triple Remedy AM Gel Cream',
#  'Elizabeth Arden Advanced Ceramide Capsules Daily Youth Restoring Eye Serum',
# ...

# %% [markdown]
# ## i'm going to try using Selenium here....

# %%
# !pip install selenium
